# %% [markdown]
# # HTMDEC DMS API Example
#
# This example demonstrates how to use the new HTMDEC DMS `/form` and `/entry` REST API endpoints to search for BIRDSHOT data which can be converted to a Pandas dataframe for analysis and visualization.
#
# The `birdshot.py` module implements some example utility functions for querying, analyzing, and visualizing BIRDSHOT data.

# %% [markdown]
# ### Note:
# During the ingest process, form data collected by Contextualize in the Campaign 1 structure was converted to the [Campaign 2 structure](https://docs.google.com/document/d/1FpiXwLQi8QAOuLB0Xr80V14qGfqtyCpT/edit). This means that:
# * Sample IDs were converted to the Campaign 2 structure
# * Campaign 1 "child" sample numbers (T*nn*) have been replaced with ordinal letters (a, b, c, ...)

# %% [markdown]
# ### Using the REST API
#
# The [Girder Client](https://girder.readthedocs.io/en/latest/python-client.html) can be used to query the REST endpoints directly. When running via the DMS, the API URL and user token required for access are available in the current environment.

# %%
from girder_client import GirderClient
import os
import json
import pandas as pd

# Connect to the Girder instance using the API key
client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.authenticate(apiKey=os.environ["GIRDER_API_KEY"])
# Out:
# {'_id': '6424ac394236ff9b0883f243'}

# %%
# Fetch a few entries to inspect their structure
entries = client.get('entry', parameters={'limit': 5})

import pprint
pprint.pprint(entries[0])  # Look at the first entry to explore keys
# Out:
# {'_id': '66310e7b1b56c53abc7e0fb1',
#  'created': '2024-04-30T15:30:03.326000+00:00',
#  'data': {'Arc Melting': {'3 Part Sections': {'1': 90.0, '2': 90.0, '3': 110.0},
#                           '3-Parts Pre-Mn Melting': {'1': '', '2': '', '3': ''},
#                           'Full Ingot': {'1': 110.0,
#                                          '2': 145.0,
#                                          '3': 145.0,
#                                          '4': 145.0,
#                                          '5': 145.0,
#                                          '6': 145.0,
#                                          '7': 175.0},
#                           'Ingot Mass Information': {'Final Ingot Mass': 29.9995,
#                                                      'Mass Loss': 0.0},
#                           'Process Overview': {'Completed By': 'Daniel',
#                                                'Finish Date': '2023-06-04',
#                                                'Start Date': '2023-05-30',
#                                                'Time Spent': '25:00'},
#                           'Surface': {'1': ''},
#                           'VAM Details': {'Argon Pressure': '850-900',
#                                           'Diffusion': 'Before Each Melt',
#                                           'Ingot Location': 8.0,
#                                           'Initial Purging Times': 3.0,
#                                           'Vacuum Before Melt': 5e-05}},
#           'Material Preparation': {'Process Overview': {'Completed By': 'Wenle',
#                                                         'Finish Date': '2023-06-02',
#                                                         'Start Date': '2023-05-18',
#                                                         'Time Spent': '3:00'},
#                                    'Target Mass': {'Al': 0.0,
#                                                    'Co': 3.1266,
#                                                    'Cr': 1.3793,
#                                                    'Cu': 0.0,
#                                                    'Fe': 2.9627,
#                                                    'Mn': 0.0,
#                                                    'Ni': 17.1262,
#                                                    'Total': 30.0,
#                                                    'V': 5.4052},
#                                    'Weighed Mass': {'Al': 0.0,
#                                                     'Co': 3.1296,
#                                                     'Cr': 1.3778,
#                                                     'Cu': 0.0,
#                                                     'Fe': 2.9613,
#                                                     'Mn': 0.0,
#                                                     'Ni': 17.1246,
#                                                     'Total': 29.9985,
#                                                     'V': 5.4052},
#                                    'elements': {'Al': True,
#                                                 'Co': True,
#                                                 'Cr': True,
#                                                 'Cu': False,
#                                                 'Fe': True,
#                                                 'Mn': False,
#                                                 'Ni': True,
#                                                 'V': True}},
#           'Notes': '',
#           'sampleId': 'AAE13_VAM-A',
#           'suffix': 'Syn',
#           'targetPath': 'AAE/VAM-A/AAE13/Syn'},
#  'files': [],
#  'folderId': '66310ca21b56c53abc7e0f9f',
#  'folders': [],
#  'formId': '66310df01b56c53abc7e0fa8',
#  'updated': '2025-03-03T13:29:49.213000+00:00'}

# %%
entry = entries[0]  # First entry from previous step
metadata = entry.get('meta', {})
print(metadata.keys())  # This shows the metadata fields like 'Iteration', 'Form', etc.

# %%
from girder_client import GirderClient
import pprint

client = GirderClient(apiUrl="https://data.htmdec.org/api/v1")
client.authenticate(apiKey="s6u5gYeQIunhjbc6XOXzV5tuEYSfdQn2ZWbaqJyU")

# Step 1: List all items in your folder
folder_id = "65fac36a60662ef084f6bc06"
items = list(client.listItem(folder_id))

print(f"Found {len(items)} items in the folder.")

# Step 2: Filter by metadata field "Iteration" = "AAA"
for item in items:
    meta = item.get("meta", {})
    if meta.get("Iteration") == "AAA":
        print(f"\nItem Name: {item['name']}")
        pprint.pprint(meta)

# %%
# Look at the metadata keys in the first few items
for i, item in enumerate(items[:5]):
    print(f"\nItem {i} metadata keys: {item.get('meta', {}).keys()}")

# %%
# Look at the metadata keys in the first few items
for i, item in enumerate(items[:5]):
    print(f"\nItem {i} metadata keys: {item.get('meta', {}).keys()}")

# %%
# client.get('entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000})

# %% [markdown]
# To query VAM data from iteration 1 (AAA) across all forms, use the `/entry/search` endpoint to query the Sample ID. Data is returned in JSON:

# %%
iteration = 'AAA'
raw_data = client.get(
        'entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000}
)
raw_data[0]["data"]
# Out:
# {'Forging': {'Ingot Condition': {'Soak Time': 30, 'Temperature': 1100},
#   'Ingot Dimensions After': {'Length': 44.7,
#    'Thickness': 3.8,
#    'Thickness Reduction': -63.2,
#    'Width': 27},
#   'Ingot Dimensions Before': {'Length': 37.5,
#    'Thickness': 10.3,
#    'Width': 14.3},
#   'Maximum Load': [{'Maximum Load Step': 244.2}],
#   'Press Temperature': 397,
#   'Process Overview': {'Completed By': 'Robert & Michael',
#    'Finish Date': '2022-10-03',
#    'Start Date': '2022-09-30',
#    'Time Spent': '7:00'}},
#  'Homogenization': {'Process Overview': {'Completed By': 'Michael',
#    'Finish Date': '2022-10-02',
#    'Start Date': '2022-09-28',
#    'Time Spent': '6:00'},
#   'Purging Sequence Pressure': {'1': 4.8e-05,
#    '2': 3.8e-05,
#    '3': 3e-05,
#    '4': 1.5e-05},
#   'Thermal Conditions': {'Atmosphere': 'Ar',
#    'Cooling Rate': 'FC',
#    'Duration': 24,
#    'Pressure': 5,
#    'Temperature': 1150}},
#  'Notes': '',
#  'sampleId': 'AAA01_VAM-B',
#  'suffix': 'Syn',
#  'targetPath': 'AAA/VAM-B/AAA01/Syn'}

# %% [markdown]
# Use the `/form` and `entry` endpoints to query data from a specific form:

# %%
form_name = 'tensile-details.json'
form = client.get('form', parameters={'entryFileName': form_name, 'limit': 1000})
form[0]['_id']

tensile_data = client.get('entry', parameters={'formId': form[0]['_id'], 'limit': 1000})
tensile_data[0]["data"]

# %% [markdown]
# ### Using the `birdshot` Module
#
# The `birdshot.py` module implements a few helper functions to query the REST API and convert data into a single Pandas dataframe for analysis:

# %%
import birdshot

# %% [markdown]
# The `query()` method takes the iteration identifier as an argument and returns a dataframe of results from multiple characterization methods. The example dataframe is intended to reproduce the information available in the Summary Synthesis Results (for example see [HTMDEC AAB Summary Synthesis Results](https://docs.google.com/spreadsheets/d/15cdImpOComsvUpAIq20_nyff65WVzN_q/)).

# %%
#client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
#client.token = os.environ["GIRDER_TOKEN"]
#client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])
df = birdshot.query("AAA")
df
# Out:
#              Target Composition (%).Al  Target Composition (%).Co  \
# AAA01_VAM-B                          0                         45
# AAA02_VAM-B                          0                         30
# AAA03_VAM-B                          0                         30
# AAA04_VAM-B                          0                         25
# AAA05_VAM-B                          0                         10
# AAA06_VAM-B                          0                         35
# AAA07_VAM-B                          0                         55
# AAA08_VAM-B                          0                         10
# AAA09_VAM-B                          5                          0
# AAA10_VAM-B                          0                          5
# AAA11_VAM-B                          0                         15
# AAA12_VAM-B                          5                         15
# AAA13_VAM-B                          5                         10
# AAA14_VAM-B                          0                         25
# AAA15_VAM-B                          5                          0
# AAA16_VAM-B                          0                          5
#
#              Target Composition (%).Cr  Target Composition (%).Cu  \
# AAA01_VAM-B                         10                          0
# AAA02_VAM-B                         10                          0
# AAA03_VAM-B                          5                          0
# AAA04_VAM-B                         10                          0
# AAA05_VAM-B                         10                          0
# AAA06_VAM-B                         25                          0
# AAA07_VAM-B                         10                          0
# AAA08_VAM-B                         10                          0
# AAA09_VAM-B                          5                          0
# AAA10_VAM-B                         15                          0
# AAA11_VAM-B                          5                          0
# AAA12_VAM-B                          5                          0
# AAA13_VAM-B                          5                          0
# AAA14_VAM-B                         10                          0
# AAA15_VAM-B                          5                          0
# AAA16_VAM-B                         10                          0
#
#              Target Composition (%).Fe  Target Composition (%).Mn  \
# AAA01_VAM-B                         20                          0
# AAA02_VAM-B                          5                          0
# AAA03_VAM-B                         30                          0
# AAA04_VAM-B                         20                          0
# AAA05_VAM-B                         55                          0
# AAA06_VAM-B                          5                          0
# AAA07_VAM-B                         10                          0
# AAA08_VAM-B                         25                          0
# AAA09_VAM-B                         25                          0
# AAA10_VAM-B                          5                          0
# AAA11_VAM-B                         45                          0
# AAA12_VAM-B                          5                          0
# AAA13_VAM-B                         25                          0
# AAA14_VAM-B                          5                          0
# AAA15_VAM-B                         45                          0
# AAA16_VAM-B                         10                          0
#
#              Target Composition (%).Ni  Target Composition (%).V XRD.Phase  \
# AAA01_VAM-B                         15                        10       FCC
# AAA02_VAM-B                         45                        10       FCC
# AAA03_VAM-B                         20                        15       FCC
# AAA04_VAM-B                         40                         5       FCC
# AAA05_VAM-B                         25                         0       FCC
# AAA06_VAM-B                         30                         5       FCC
# AAA07_VAM-B                         15                        10       FCC
# AAA08_VAM-B                         50                         5       FCC
# AAA09_VAM-B                         60                         5       FCC
# AAA10_VAM-B                         70                         5       FCC
# AAA11_VAM-B                         30                         5       FCC
# AAA12_VAM-B                         65                         5       FCC
# AAA13_VAM-B                         50                         5       FCC
# AAA14_VAM-B                         35                        25       FCC
# AAA15_VAM-B                         45                         0       FCC
# AAA16_VAM-B                         55                        20       FCC
#
#             XRD.Lattice Parameters  ...  Maximum ∂2σ/∂ε2.a  UTS/YS Ratio.a  \
# AAA01_VAM-B                  3.583  ...              -1726        1.728953
# AAA02_VAM-B                  3.571  ...              -3363        1.544610
# AAA03_VAM-B                  3.605  ...               -779        1.494505
# AAA04_VAM-B                  3.578  ...              -4567        1.603104
# AAA05_VAM-B                  3.594  ...              -2342        1.446602
# AAA06_VAM-B                  3.580  ...              -1945        1.814815
# AAA07_VAM-B                  3.579  ...              -3035        1.579470
# AAA08_VAM-B                  3.574  ...              -3360        1.649880
# AAA09_VAM-B                  3.585  ...               1660        1.887179
# AAA10_VAM-B                  3.570  ...               -748        1.758025
# AAA11_VAM-B                  3.602  ...             -10496        1.505495
# AAA12_VAM-B                  3.564  ...              -2675        1.589286
# AAA13_VAM-B                  3.584  ...               1789        2.981818
# AAA14_VAM-B                  3.604  ...              -1327        1.905316
# AAA15_VAM-B                  3.602  ...               1156        1.909091
# AAA16_VAM-B                  3.595  ...              -1963        1.902913
#
#              Ultimate Tensile Strength.a  Yield Strength.a  Elastic Modulus.b  \
# AAA01_VAM-B                          842               487                196
# AAA02_VAM-B                          831               538                228
# AAA03_VAM-B                          680               455                206
# AAA04_VAM-B                          723               451                194
# AAA05_VAM-B                          447               309                168
# AAA06_VAM-B                          931               513                239
# AAA07_VAM-B                          954               604                220
# AAA08_VAM-B                          688               417                193
# AAA09_VAM-B                          736               390                181
# AAA10_VAM-B                          712               405                208
# AAA11_VAM-B                          548               364                168
# AAA12_VAM-B                          623               392                215
# AAA13_VAM-B                          820               275                194
# AAA14_VAM-B                         1147               602                196
# AAA15_VAM-B                          567               297                157
# AAA16_VAM-B                          980               515                213
#
#              Elongation.b  Maximum ∂2σ/∂ε2.b  UTS/YS Ratio.b  \
# AAA01_VAM-B            21              -3671        1.605416
# AAA02_VAM-B            24              -3479        1.779070
# AAA03_VAM-B            22               -242        1.690867
# AAA04_VAM-B            20              -1436        1.624021
# AAA05_VAM-B            17              -2094        1.324324
# AAA06_VAM-B            21              -4975        1.512384
# AAA07_VAM-B            27              -2321        1.778793
# AAA08_VAM-B            14              -6069        1.488739
# AAA09_VAM-B            40               1349        2.371601
# AAA10_VAM-B            28               -877        2.031830
# AAA11_VAM-B            14             -11890        1.383886
# AAA12_VAM-B            18                  0        1.365535
# AAA13_VAM-B            28                216        1.731591
# AAA14_VAM-B            28              -2477        1.908805
# AAA15_VAM-B            24                 -8        1.956349
# AAA16_VAM-B            26              -2146        1.657512
#
#              Ultimate Tensile Strength.b  Yield Strength.b
# AAA01_VAM-B                          830               517
# AAA02_VAM-B                          918               516
# AAA03_VAM-B                          722               427
# AAA04_VAM-B                          622               383
# AAA05_VAM-B                          441               333
# AAA06_VAM-B                          977               646
# AAA07_VAM-B                          973               547
# AAA08_VAM-B                          661               444
# AAA09_VAM-B                          785               331
# AAA10_VAM-B                          766               377
# AAA11_VAM-B                          584               422
# AAA12_VAM-B                          523               383
# AAA13_VAM-B                          729               421
# AAA14_VAM-B                         1214               636
# AAA15_VAM-B                          493               252
# AAA16_VAM-B                         1026               619
#
# [16 rows x 30 columns]

# %%
raw_data = birdshot.query("AAA", raw=True)
print(raw_data)
# Out:
# [{'_id': '66310eda1b56c53abc7e1522', 'created': '2024-04-30T15:31:38.935000+00:00', 'data': {'Forging': {'Ingot Condition': {'Soak Time': 30, 'Temperature': 1100}, 'Ingot Dimensions After': {'Length': 44.7, 'Thickness': 3.8, 'Thickness Reduction': -63.2, 'Width': 27}, 'Ingot Dimensions Before': {'Length': 37.5, 'Thickness': 10.3, 'Width': 14.3}, 'Maximum Load': [{'Maximum Load Step': 244.2}], 'Press Temperature': 397, 'Process Overview': {'Completed By': 'Robert & Michael', 'Finish Date': '2022-10-03', 'Start Date': '2022-09-30', 'Time Spent': '7:00'}}, 'Homogenization': {'Process Overview': {'Completed By': 'Michael', 'Finish Date': '2022-10-02', 'Start Date': '2022-09-28', 'Time Spent': '6:00'}, 'Purging Sequence Pressure': {'1': 4.8e-05, '2': 3.8e-05, '3': 3e-05, '4': 1.5e-05}, 'Thermal Conditions': {'Atmosphere': 'Ar', 'Cooling Rate': 'FC', 'Duration': 24, 'Pressure': 5, 'Temperature': 1150}}, 'Notes': '', 'sampleId': 'AAA01_VAM-B', 'suffix': 'Syn', 'targetPath': 'AAA/VAM-B/AAA01/Syn'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310deb1b56c53abc7e0fa1', 'updated': '2024-04-30T15:41:45.783000+00:00'}, {'_id': '66310edb1b56c53abc7e1526', 'created': '2024-04-30T15:31:39.226000+00:00', 'data': {'Arc Melting': {'3 Part Sections': {'1': 90.0, '2': 90.0, '3': 90.0}, '3-Parts Pre-Mn Melting': {'1': '', '2': '', '3': ''}, 'Full Ingot': {'1': 125.0, '2': 125.0, '3': 125.0, '4': 125.0, '5': 125.0, '6': 145.0, '7': 145.0}, 'Ingot Mass Information': {'Final Ingot Mass': 30.0011, 'Mass Loss': 0.01}, 'Process Overview': {'Completed By': 'Daniel', 'Finish Date': '2022-09-29', 'Start Date': '2022-09-27', 'Time Spent': '3:00'}, 'Surface': {'1': ''}, 'VAM Details': {'Argon Pressure': '850-900', 'Diffusion': 'Before Each Melt', 'Ingot Location': 3.0, 'Initial Purging Times': 3.0, 'Vacuum Before Melt': 5e-05}}, 'Material Preparation': {'Process Overview': {'Completed By': 'Wenle & Daniel', 'Finish Date': '2022-09-27', 'Start Date': '2022-09-26', 'Time Spent': '1:00'}, 'Target Mass': {'Al': 0.0, 'Co': 14.0103, 'Cr': 2.7469, 'Cu': 0.0, 'Fe': 5.9005, 'Mn': 0.0, 'Ni': 4.6511, 'Total': 30.0, 'V': 2.6912}, 'Weighed Mass': {'Al': 0.0, 'Co': 14.0129, 'Cr': 2.7473, 'Cu': 0.0, 'Fe': 5.8987, 'Mn': 0.0, 'Ni': 4.6505, 'Total': 30.0037, 'V': 2.6943}, 'elements': {'Al': True, 'Co': True, 'Cr': True, 'Cu': False, 'Fe': True, 'Mn': False, 'Ni': True, 'V': True}}, 'Notes': '', 'sampleId': 'AAA01_VAM-B', 'suffix': 'Syn', 'targetPath': 'AAA/VAM-B/AAA01/Syn'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310df01b56c53abc7e0fa8', 'updated': '2025-03-03T13:30:01.525000+00:00'}, {'_id': '66310edb1b56c53abc7e152b', 'created': '2024-04-30T15:31:39.717000+00:00', 'data': {'Process Overview': {'End Date': '2022-09-30', 'Start Date': '2022-09-30', 'Time Spent': '0:05'}, 'Results': {'Notes': '', 'files': {'file': '1ViwJ-TFFzeA5t0hR4-5bukAyF_AGT8qr', 'sampleId': 'AAA01_VAM-B', 'targetPath': 'AAA/VAM-B/AAA01/Microhardness'}}, 'Test Information': {'Dwell Time': 0, 'Indents per Sample': 10, 'Load': 300, 'Type': 'Vickers'}, 'sampleId': 'AAA01_VAM-B', 'suffix': 'Microhardness', 'targetPath': 'AAA/VAM-B/AAA01/Microhardness'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310ded1b56c53abc7e0fa3', 'updated': '2024-04-30T15:41:46.733000+00:00'}, {'_id': '66310edc1b56c53abc7e1530', 'created': '2024-04-30T15:31:40.022000+00:00', 'data': {'Completed By': 'Anup & Daniel', 'End Date': '2022-10-17', 'Start Date': '2022-10-14', 'Time Spent': '10:00', 'XRD Process Overview': {'Beam Amperage': 40, 'Beam Voltage': 40, 'Scan Type': 'θ-2θ', 'TAMU Instrument Details': {'Collimator': 1, 'Distance': 19.96, 'Frames': 3, 'Phi': 0, 'Psi': 0, 'Results': {'Notes': '', 'Phase Information': [{'Structure': 'FCC', 'a': '3.583', 'b': '', 'c': '', 'α': '', 'β': '', 'γ': ''}], 'dataFiles': {'file': '1xgZ6uUmbEnQx0WFG5BOLJ-3c_xGwv6dw,1floqG4J2jaTu_f4NUsK5og5Uv5_Dzela,1wz57pm7IEkmpi3a-KB_x4dmob8KLLKXA,11 ...

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
#client.token = os.environ["GIRDER_TOKEN"]
client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])
print(client.get('user/me'))
raw_data_direct = client.get("entry/search", parameters={"query": "AAA", "limit": 1000})
print(raw_data_direct)

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.token = os.environ["GIRDER_TOKEN"]

# 1. List all collections and find the one named "BIRDSHOT (Center)"
collections = client.listCollection()
for col in collections:
    print(col['name'], col['_id'])
    # If col['name'] == 'BIRDSHOT (Center)', store its _id
    if col['name'] == 'BIRDSHOT (Center)':
        birdshot_collection_id = col['_id']

# 2. List the subfolders of the BIRDSHOT (Center) collection
folders = client.listFolder(birdshot_collection_id, parentType='collection')
for folder in folders:
    print(folder['name'], folder['_id'])
    # If folder['name'] == 'sample_data', store its _id
    if folder['name'] == 'sample_data':
        sample_data_folder_id = folder['_id']

# 3. List subfolders inside "sample_data"
subfolders = client.listFolder(sample_data_folder_id)
for sf in subfolders:
    print(sf['name'], sf['_id'])

# %%
df = birdshot.query("AAA")

# %%
import sys
print(sys.executable)

# %%
import os
print(os.environ.get("GIRDER_API_URL"))
print(os.environ.get("GIRDER_API_KEY"))
print(os.environ.get("TMP_URL"))
# Out:
# https://data.htmdec.org/api/v1
# None
# localhost:8888

# %%
import birdshot
import pandas as pd

data = birdshot.query("AAA", raw=True)  # Assuming you can modify or patch query to return early
df = pd.DataFrame.from_dict(data, orient='index')
print("Actual columns:", df.columns)

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])

# Send the same query that birdshot.query("AAA") uses
raw_data = client.get(
    'entry/search',
    parameters={'query': '^AAA.._VAM-.', 'limit': 1000}
)

# If you want to preview what keys/structure it has:
import json
print(json.dumps(raw_data[:2], indent=2))  # print a couple entries

# Create a DataFrame to see the actual columns
import pandas as pd
df = pd.DataFrame.from_records(raw_data)
print("Actual columns:", df.columns.tolist())

# %%
import birdshot
import importlib

importlib.reload(birdshot)

# %%
birdshot.show_plot()

# %%
import birdshot
import os
import socket

# Find a free port
def get_free_port():
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind(('', 0))  # Let OS pick an available port
        return s.getsockname()[1]

free_port = get_free_port()
os.environ['TMP_URL'] = 'localhost:8888'  # This should match your running Jupyter server

def patched_show_plot():
    from dash import Dash
    import dash_bootstrap_components as dbc

    app = Dash(
        __name__,
        external_stylesheets=[dbc.themes.BOOTSTRAP, dbc.icons.FONT_AWESOME],
        requests_pathname_prefix=f"/proxy/{free_port}/",
    )
    app.layout = birdshot.serve_layout
    app.run(
        debug=False,
        jupyter_mode="jupyterlab",
        host="0.0.0.0",
        port=free_port,
        jupyter_server_url=f"http://{os.environ['TMP_URL']}/",
    )

birdshot.show_plot = patched_show_plot
birdshot.show_plot()

# %% [markdown]
# ### Working on understanding the queries to get something interesting into the dataframe

# %%
# Define the iteration value
iteration = 'AAA'

# Build the query string using the iteration variable
query_string = f"^{iteration}.._VAM-."

# Construct the birdshot.query statement (as it would be used)
query_statement = f"birdshot.query('entry/search', parameters={{'query': '{query_string}', 'limit': 1000}})"

# Print the constructed query statement
print(query_statement)

# %%
iteration = 'AAA'
raw_data = client.get(
        'entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000}
)
raw_data[0]["data"]

# %%
birdshot.query('entry/search', parameters={'query': '^AAA.._VAM-.', 'limit': 1000})
