# %% [markdown]
# # HTMDEC DMS API Example
#
# This example introduces use of the HTMDEC DMS `/form` and `/entry` REST API endpoints to search for BIRDSHOT data.  The notebooks queries the DMS for BIRDSHOT data which is loaded into a Pandas dataframe for analysis and visualization.
#
# The `birdshot.py` module implements some example utility functions for querying, analyzing, and visualizing BIRDSHOT data.

# %% [markdown]
# ## TODO: write a description of the structure so people understand what forms and entries are

# %% [markdown]
# ### Note:
# During the ingest process, form data in the Campaign 1 structure (originally organized by Contextualized during their data seedling award)  was converted to the [Campaign 2 structure](https://docs.google.com/document/d/1FpiXwLQi8QAOuLB0Xr80V14qGfqtyCpT/edit). This means that:
# * Sample IDs were converted to the Campaign 2 structure
# * Campaign 1 "child" sample numbers (T*nn*) have been replaced with ordinal letters (a, b, c, ...)

# %% [markdown]
# ### Using the REST API
#
# The [Girder Client](https://girder.readthedocs.io/en/latest/python-client.html) can be used to query the REST endpoints directly. When running through the DMS, the API URL and a user token are required for access are available in the current environment. In this notebook, we will run from outside the DMS, in a local Jupyter environment that is likely on someone's laptop, so authentication will happen with an API Key created by the user in their account profile on the DMS platform. This authentication by key versus token is the fundamental difference between this example and the one shown as a Tale on the data.htmdec.org platform.

# %% [markdown]
# ---
#
# ### Set up
# 1. Import modules
# 2. Read authentication information from environmental variables

# %%
from girder_client import GirderClient
import os
import json
import pandas as pd

# Connect to the Girder instance using the API key
client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.authenticate(apiKey=os.environ["GIRDER_API_KEY"])
# Out:
# {'_id': '6424ac394236ff9b0883f243'}

# %%
# Fetch a few entries to inspect their structure
entries = client.get('entry', parameters={'limit': 5})

import pprint
pprint.pprint(entries[0])  # Look at the first entry to explore keys
# Out:
# {'_id': '66310e7b1b56c53abc7e0fb1',
#  'created': '2024-04-30T15:30:03.326000+00:00',
#  'data': {'Arc Melting': {'3 Part Sections': {'1': 90.0, '2': 90.0, '3': 110.0},
#                           '3-Parts Pre-Mn Melting': {'1': '', '2': '', '3': ''},
#                           'Full Ingot': {'1': 110.0,
#                                          '2': 145.0,
#                                          '3': 145.0,
#                                          '4': 145.0,
#                                          '5': 145.0,
#                                          '6': 145.0,
#                                          '7': 175.0},
#                           'Ingot Mass Information': {'Final Ingot Mass': 29.9995,
#                                                      'Mass Loss': 0.0},
#                           'Process Overview': {'Completed By': 'Daniel',
#                                                'Finish Date': '2023-06-04',
#                                                'Start Date': '2023-05-30',
#                                                'Time Spent': '25:00'},
#                           'Surface': {'1': ''},
#                           'VAM Details': {'Argon Pressure': '850-900',
#                                           'Diffusion': 'Before Each Melt',
#                                           'Ingot Location': 8.0,
#                                           'Initial Purging Times': 3.0,
#                                           'Vacuum Before Melt': 5e-05}},
#           'Material Preparation': {'Process Overview': {'Completed By': 'Wenle',
#                                                         'Finish Date': '2023-06-02',
#                                                         'Start Date': '2023-05-18',
#                                                         'Time Spent': '3:00'},
#                                    'Target Mass': {'Al': 0.0,
#                                                    'Co': 3.1266,
#                                                    'Cr': 1.3793,
#                                                    'Cu': 0.0,
#                                                    'Fe': 2.9627,
#                                                    'Mn': 0.0,
#                                                    'Ni': 17.1262,
#                                                    'Total': 30.0,
#                                                    'V': 5.4052},
#                                    'Weighed Mass': {'Al': 0.0,
#                                                     'Co': 3.1296,
#                                                     'Cr': 1.3778,
#                                                     'Cu': 0.0,
#                                                     'Fe': 2.9613,
#                                                     'Mn': 0.0,
#                                                     'Ni': 17.1246,
#                                                     'Total': 29.9985,
#                                                     'V': 5.4052},
#                                    'elements': {'Al': True,
#                                                 'Co': True,
#                                                 'Cr': True,
#                                                 'Cu': False,
#                                                 'Fe': True,
#                                                 'Mn': False,
#                                                 'Ni': True,
#                                                 'V': True}},
#           'Notes': '',
#           'sampleId': 'AAE13_VAM-A',
#           'suffix': 'Syn',
#           'targetPath': 'AAE/VAM-A/AAE13/Syn'},
#  'files': [],
#  'folderId': '66310ca21b56c53abc7e0f9f',
#  'folders': [],
#  'formId': '66310df01b56c53abc7e0fa8',
#  'updated': '2025-03-03T13:29:49.213000+00:00'}

# %%
entry = entries[0]  # First entry from previous step
metadata = entry.get('meta', {})
print(metadata.keys())  # This shows the metadata fields like 'Iteration', 'Form', etc.

# %%
from girder_client import GirderClient
import pprint

client = GirderClient(apiUrl="https://data.htmdec.org/api/v1")
client.authenticate(apiKey="s6u5gYeQIunhjbc6XOXzV5tuEYSfdQn2ZWbaqJyU")

# Step 1: List all items in your folder
folder_id = "65fac36a60662ef084f6bc06"
items = list(client.listItem(folder_id))

print(f"Found {len(items)} items in the folder.")

# Step 2: Filter by metadata field "Iteration" = "AAA"
for item in items:
    meta = item.get("meta", {})
    if meta.get("Iteration") == "AAA":
        print(f"\nItem Name: {item['name']}")
        pprint.pprint(meta)

# %%
# Look at the metadata keys in the first few items
for i, item in enumerate(items[:5]):
    print(f"\nItem {i} metadata keys: {item.get('meta', {}).keys()}")

# %%
# Look at the metadata keys in the first few items
for i, item in enumerate(items[:5]):
    print(f"\nItem {i} metadata keys: {item.get('meta', {}).keys()}")

# %%
# client.get('entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000})

# %% [markdown]
# To query VAM data from iteration 1 (AAA) across all forms, use the `/entry/search` endpoint to query the Sample ID. Data is returned in JSON:

# %%
iteration = 'AAA'
raw_data = client.get(
        'entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000}
)
raw_data[0]["data"]
# Out:
# {'Forging': {'Ingot Condition': {'Soak Time': 30, 'Temperature': 1100},
#   'Ingot Dimensions After': {'Length': 44.7,
#    'Thickness': 3.8,
#    'Thickness Reduction': -63.2,
#    'Width': 27},
#   'Ingot Dimensions Before': {'Length': 37.5,
#    'Thickness': 10.3,
#    'Width': 14.3},
#   'Maximum Load': [{'Maximum Load Step': 244.2}],
#   'Press Temperature': 397,
#   'Process Overview': {'Completed By': 'Robert & Michael',
#    'Finish Date': '2022-10-03',
#    'Start Date': '2022-09-30',
#    'Time Spent': '7:00'}},
#  'Homogenization': {'Process Overview': {'Completed By': 'Michael',
#    'Finish Date': '2022-10-02',
#    'Start Date': '2022-09-28',
#    'Time Spent': '6:00'},
#   'Purging Sequence Pressure': {'1': 4.8e-05,
#    '2': 3.8e-05,
#    '3': 3e-05,
#    '4': 1.5e-05},
#   'Thermal Conditions': {'Atmosphere': 'Ar',
#    'Cooling Rate': 'FC',
#    'Duration': 24,
#    'Pressure': 5,
#    'Temperature': 1150}},
#  'Notes': '',
#  'sampleId': 'AAA01_VAM-B',
#  'suffix': 'Syn',
#  'targetPath': 'AAA/VAM-B/AAA01/Syn'}

# %% [markdown]
# Use the `/form` and `entry` endpoints to query data from a specific form:

# %%
form_name = 'tensile-details.json'
form = client.get('form', parameters={'entryFileName': form_name, 'limit': 1000})
form[0]['_id']

tensile_data = client.get('entry', parameters={'formId': form[0]['_id'], 'limit': 1000})
tensile_data[0]["data"]

# %% [markdown]
# ### Using the `birdshot` Module
#
# The `birdshot.py` module implements a few helper functions to query the REST API and convert data into a single Pandas dataframe for analysis:

# %%
import birdshot

# %% [markdown]
# The `query()` method takes the iteration identifier as an argument and returns a dataframe of results from multiple characterization methods. The example dataframe is intended to reproduce the information available in the Summary Synthesis Results (for example see [HTMDEC AAB Summary Synthesis Results](https://docs.google.com/spreadsheets/d/15cdImpOComsvUpAIq20_nyff65WVzN_q/)).

# %%
#client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
#client.token = os.environ["GIRDER_TOKEN"]
#client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])
df = birdshot.query("BBA")
df
# Out:
#              Target Composition (%).Al  Target Composition (%).Co  \
# BBA01_VAM-A                          4                          8
# BBA02_VAM-A                          4                         16
# BBA03_VAM-A                          4                         12
# BBA04_VAM-A                          0                         12
# BBA05_VAM-A                          4                         12
# BBA06_VAM-A                          4                          0
# BBA07_VAM-A                          4                         12
# BBA08_VAM-A                          0                         24
# BBA09_VAM-A                          4                         16
# BBA10_VAM-A                          4                          0
# BBA11_VAM-A                          0                         16
# BBA12_VAM-A                          0                          0
# BBA13_VAM-A                          4                         20
# BBA14_VAM-A                          0                         16
# BBA15_VAM-A                          0                         20
# BBA16_VAM-A                          4                         12
# BBA17_VAM-A                          4                          0
# BBA18_VAM-A                          0                          4
# BBA19_VAM-A                          4                          8
#
#              Target Composition (%).Cr  Target Composition (%).Cu  \
# BBA01_VAM-A                          4                          4
# BBA02_VAM-A                          0                          4
# BBA03_VAM-A                          8                          4
# BBA04_VAM-A                          8                          4
# BBA05_VAM-A                          8                          0
# BBA06_VAM-A                          8                          4
# BBA07_VAM-A                          0                          0
# BBA08_VAM-A                          8                          0
# BBA09_VAM-A                          8                          0
# BBA10_VAM-A                          4                          0
# BBA11_VAM-A                          0                          4
# BBA12_VAM-A                          8                          4
# BBA13_VAM-A                          4                          4
# BBA14_VAM-A                          8                          4
# BBA15_VAM-A                          8                          4
# BBA16_VAM-A                          0                         12
# BBA17_VAM-A                          4                          4
# BBA18_VAM-A                          8                          4
# BBA19_VAM-A                          0                         12
#
#              Target Composition (%).Fe  Target Composition (%).Mn  \
# BBA01_VAM-A                         16                         12
# BBA02_VAM-A                         12                          8
# BBA03_VAM-A                         16                          8
# BBA04_VAM-A                         16                         20
# BBA05_VAM-A                          8                          8
# BBA06_VAM-A                         24                         12
# BBA07_VAM-A                         16                          8
# BBA08_VAM-A                         12                         16
# BBA09_VAM-A                         12                          0
# BBA10_VAM-A                         20                          8
# BBA11_VAM-A                         20                         20
# BBA12_VAM-A                         16                         12
# BBA13_VAM-A                         16                          0
# BBA14_VAM-A                         16                         20
# BBA15_VAM-A                          0                         20
# BBA16_VAM-A                         20                          8
# BBA17_VAM-A                         16                         12
# BBA18_VAM-A                         16                         20
# BBA19_VAM-A                         20                          8
#
#              Target Composition (%).Ni  Target Composition (%).V  \
# BBA01_VAM-A                         48                         4
# BBA02_VAM-A                         52                         4
# BBA03_VAM-A                         48                         0
# BBA04_VAM-A                         36                         4
# BBA05_VAM-A                         56                         4
# BBA06_VAM-A                         44                         4
# BBA07_VAM-A                         52                         8
# BBA08_VAM-A                         32                         8
# BBA09_VAM-A                         48                        12
# BBA10_VAM-A                         52                        12
# BBA11_VAM-A                         28                        12
# BBA12_VAM-A                         52                         8
# BBA13_VAM-A                         52                         0
# BBA14_VAM-A                         36                         0
# BBA15_VAM-A                         44                         4
# BBA16_VAM-A                         44                         0
# BBA17_VAM-A                         56                         4
# BBA18_VAM-A                         44                         4
# BBA19_VAM-A                         48                         0
#
#              Measured Composition (%).Al  Measured Composition (%).Co  ...  \
# BBA01_VAM-A                     4.074000                     8.169333  ...
# BBA02_VAM-A                     4.166667                    14.974667  ...
# BBA03_VAM-A                     4.252667                    12.136000  ...
# BBA04_VAM-A                          NaN                          NaN  ...
# BBA05_VAM-A                     4.068000                    12.248667  ...
# BBA06_VAM-A                     4.198000                     0.000000  ...
# BBA07_VAM-A                     5.030000                    12.254667  ...
# BBA08_VAM-A                     0.000000                    22.892667  ...
# BBA09_VAM-A                     4.898667                    16.117333  ...
# BBA10_VAM-A                     4.388000                     0.000000  ...
# BBA11_VAM-A                     0.000000                    16.119333  ...
# BBA12_VAM-A                     0.000000                     0.000000  ...
# BBA13_VAM-A                     4.016000                    20.379333  ...
# BBA14_VAM-A                     0.000000                    16.092667  ...
# BBA15_VAM-A                     0.000000                    19.905333  ...
# BBA16_VAM-A                     4.146667                    12.291333  ...
# BBA17_VAM-A                     4.216667                     0.000000  ...
# BBA18_VAM-A                     0.000000                     4.071333  ...
# BBA19_VAM-A                     3.977333                     8.110000  ...
#
#              Maximum ∂2σ/∂ε2.b  UTS/YS Ratio.b  Ultimate Tensile Strength.b  \
# BBA01_VAM-A         826.407720        2.433921                   608.363077
# BBA02_VAM-A         298.089239        2.301910                   677.692158
# BBA03_VAM-A         562.282798        2.606923                   579.563986
# BBA04_VAM-A                NaN             NaN                          NaN
# BBA05_VAM-A         654.294205        2.279349                   726.744092
# BBA06_VAM-A         950.708832        2.567465                   601.019294
# BBA07_VAM-A      -35046.315706        1.098992                   374.294781
# BBA08_VAM-A         748.285761        2.481465                   676.029199
# BBA09_VAM-A      -68584.274662        1.270553                   358.572122
# BBA10_VAM-A        -486.219900        1.870213                   690.342523
# BBA11_VAM-A                NaN             NaN                          NaN
# BBA12_VAM-A         972.487832        1.256606                   196.794313
# BBA13_VAM-A        1891.641556        2.996678                   536.748634
# BBA14_VAM-A         920.262820        2.475205                   650.610738
# BBA15_VAM-A                NaN             NaN                          NaN
# BBA16_VAM-A         927.831525        2.656846                   571.008076
# BBA17_VAM-A    -1000000.000000        1.225602                   181.791749
# BBA18_VAM-A         442.285391        2.156158                   569.639535
# BBA19_VAM-A         917.066629        2.600394                   609.162911
#
#              Yield Strength.b  Elastic Modulus.c  Elongation.c  \
# BBA01_VAM-A        249.951812                NaN           NaN
# BBA02_VAM-A        294.404285         209.541831           1.0
# BBA03_VAM-A        222.317245                NaN           NaN
# BBA04_VAM-A               NaN                NaN           NaN
# BBA05_VAM-A        318.838402                NaN           NaN
# BBA06_VAM-A        234.090518                NaN           NaN
# BBA07_VAM-A        340.579997         226.467860           1.0
# BBA08_VAM-A        272.431460                NaN           NaN
# BBA09_VAM-A        282.217325                NaN           NaN
# BBA10_VAM-A        369.125009         221.709438           1.0
# BBA11_VAM-A               NaN                NaN           NaN
# BBA12_VAM-A        156.607750         221.121291           1.0
# BBA13_VAM-A        179.114539                NaN           NaN
# BBA14_VAM-A        262.851233                NaN           NaN
# BBA15_VAM-A               NaN                NaN           NaN
# BBA16_VAM-A        214.919525                NaN           NaN
# BBA17_VAM-A        148.328585         194.363638           1.0
# BBA18_VAM-A        264.191957                NaN           NaN
# BBA19_VAM-A        234.257922                NaN           NaN
#
#             Maximum ∂2σ/∂ε2.c  UTS/YS Ratio.c  Ultimate Tensile Strength.c  \
# BBA01_VAM-A               NaN             NaN                          NaN
# BBA02_VAM-A       -176.728705        2.307010                   709.610253
# BBA03_VAM-A               NaN             NaN                          NaN
# BBA04_VAM-A               NaN             NaN                          NaN
# BBA05_VAM-A               NaN             NaN                          NaN
# BBA06_VAM-A               NaN             NaN                          NaN
# BBA07_VAM-A       2606.127520        1.946526                   841.641202
# BBA08_VAM-A               NaN             NaN                          NaN
# BBA09_VAM-A               NaN             NaN                          NaN
# BBA10_VAM-A        -13.990309        2.193465                   825.504249
# BBA11_VAM-A               NaN             NaN                          NaN
# BBA12_VAM-A          7.720391        2.274542                   738.161422
# BBA13_VAM-A               NaN             NaN                          NaN
# BBA14_VAM-A               NaN             NaN                          NaN
# BBA15_VAM-A               NaN             NaN                          NaN
# BBA16_VAM-A               NaN             NaN                          NaN
# BBA17_VAM-A        127.224551        2.224421                   708.535331
# BBA18_VAM-A               NaN             NaN                          NaN
# BBA19_VAM-A               NaN             NaN                          NaN
#
#              Yield Strength.c
# BBA01_VAM-A               NaN
# BBA02_VAM-A        307.588701
# BBA03_VAM-A               NaN
# BBA04_VAM-A               NaN
# BBA05_VAM-A               NaN
# BBA06_VAM-A               NaN
# BBA07_VAM-A        432.381192
# BBA08_VAM-A               NaN
# BBA09_VAM-A               NaN
# BBA10_VAM-A        376.347128
# BBA11_VAM-A               NaN
# BBA12_VAM-A        324.531960
# BBA13_VAM-A               NaN
# BBA14_VAM-A               NaN
# BBA15_VAM-A               NaN
# BBA16_VAM-A               NaN
# BBA17_VAM-A        318.525777
# BBA18_VAM-A               NaN
# BBA19_VAM-A               NaN
#
# [19 rows x 36 columns]

# %%
raw_data = birdshot.query("AAA", raw=True)
print(raw_data)

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
#client.token = os.environ["GIRDER_TOKEN"]
client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])
print(client.get('user/me'))
raw_data_direct = client.get("entry/search", parameters={"query": "AAA", "limit": 1000})
print(raw_data_direct)
# Out:
# {'_accessLevel': 2, '_id': '6424ac394236ff9b0883f243', '_modelType': 'user', 'admin': True, 'created': '2023-03-29T21:23:05.789000+00:00', 'email': 'elbert@jhu.edu', 'emailVerified': False, 'firstName': 'David', 'groupInvites': [], 'groups': ['641893cba82b019cd3c7005f', '659ed73d60662ef084f6b385', '66ec64d20132d76f601cecf7', '67040aa897930f6e9db881c4', '671e4e6130a3240163bb785d', '67905dfda1b0b3735eefcb04', '67c1ccf744f9c11af77af053'], 'lastLogin': '2025-03-23T16:44:24.427000+00:00', 'lastName': 'Elbert', 'login': 'elbert', 'otherTokens': [{'access_token': 'Agzo3OjM3DXjXW1YjNPE39wedg0PO5BoQelDPg5kwPn95PWz2qtkC82qjom4x2WVpQbBDQBxv3g6kMFbVQwvEtVOvON', 'expires_in': 172800, 'refresh_token': 'AgdqMqrMeO0x98z3P00mxEYXje7Y4qgxKXJk6po7kE6Dqda4gmCOUzD2GQzrXP88z5O5OoODP7ybY3aDBQKqvrrxPa7DW', 'resource_server': 'usc_isrd', 'scope': 'https://auth.globus.org/scopes/a77ee64a-fb7f-11e5-810e-8c705ad34f60/deriva_all', 'state': 'aS0jtMt2Rbb0nB8lZJfubrZTIN1y3MEorNudaLYgN0p5C1luyC4kkEc06cjr2bmj.https://data.htmdec.org/#', 'token_type': 'Bearer'}, {'access_token': 'Agv0Vy4vezXOkJ0O4yNE7jnYvq0gp3NXGmaB4l1QyODeE5jnlQTzC6w4ol1Pv18QzOaeQnN6qk619NIO1Q2rXU6jejX', 'expires_in': 172800, 'refresh_token': 'Ag80OO8nWeW8j90YVWwNKJ4qnrx8w2XPlzQ3K8OeXP0g8ly3EviaUG9kEgmlykQO5xXwmXabmJPvk2MzrJpnN57We2bkB', 'resource_server': 'transfer.api.globus.org', 'scope': 'urn:globus:auth:scope:transfer.api.globus.org:all', 'state': 'aS0jtMt2Rbb0nB8lZJfubrZTIN1y3MEorNudaLYgN0p5C1luyC4kkEc06cjr2bmj.https://data.htmdec.org/#', 'token_type': 'Bearer'}], 'otp': False, 'public': True, 'size': 403093504, 'status': 'enabled'}
# [{'_id': '66310f161b56c53abc7e1872', 'created': '2024-04-30T15:32:38.096000+00:00', 'data': {'Process Overview': {'End Date': '2022-10-04', 'Start Date': '2022-10-04', 'Time Spent': '0:02'}, 'Results': {'Notes': '', 'files': {'file': '12oNSiDGRxoU501aEU1KBmpj2I2Macyht', 'sampleId': 'AAA01_DED-A', 'targetPath': 'AAA/DED-A/AAA01/Microhardness'}}, 'Test Information': {'Dwell Time': 10, 'Indents per Sample': 25, 'Load': 1000, 'Type': 'Vickers'}, 'sampleId': 'AAA01_DED-A', 'suffix': 'Microhardness', 'targetPath': 'AAA/DED-A/AAA01/Microhardness'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310ded1b56c53abc7e0fa3', 'updated': '2024-04-30T15:42:40.582000+00:00'}, {'_id': '66310f161b56c53abc7e1877', 'created': '2024-04-30T15:32:38.400000+00:00', 'data': {'EBSD and EDS Mapping': {'Beam Current': 26, 'Beam Voltage': 20, 'Dwell Time': '4 x 1', 'Low Vacuum': '25', 'Sample Tilt': 60, 'Working Distance': 18.1}, 'EDS Quantitative Analysis': {'Beam Current': 3.2, 'Beam Voltage': 20, 'Dwell Time': 1, 'Low Vacuum': 'None', 'Sample Tilt': 0, 'Working Distance': 10}, 'Notes': '', 'Process Overview': {'End Date': '2022-10-08', 'SEM Used': 'Apreo (FEI)', 'Start Date': '2022-10-08', 'Time Spent': '03:00'}, 'Results': {'Measured Composition (%)': {'Al': 0, 'Co': 0, 'Cr': 0, 'Cu': 0, 'Fe': 0, 'Mn': 0, 'Ni': 0, 'V': 0}, 'files': {'file': '', 'sampleId': 'AAA01_DED-A', 'targetPath': 'AAA/DED-A/AAA01/EDS'}}, 'sampleId': 'AAA01_DED-A', 'suffix': 'EDS', 'targetPath': 'AAA/DED-A/AAA01/EDS'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310df01b56c53abc7e0fa9', 'updated': '2024-04-30T15:42:40.909000+00:00'}, {'_id': '66310f161b56c53abc7e187c', 'created': '2024-04-30T15:32:38.691000+00:00', 'data': {'Completed By': 'Haoren', 'End Date': '2022-10-05', 'Start Date': '2022-10-04', 'Time Spent': '14:00', 'XRD Process Overview': {'Beam Amperage': 49, 'Beam Voltage': 40, 'Scan Type': '2θ-ω', 'UCSD Instrument Details': {'2θ Angle End': 80, '2θ Angle Start': 20, 'Scan Speed': 0.05, 'dataFiles': {'file': '', 'sampleId': 'AAA01_DED-A', 'targetPath': 'AAA/DED-A/AAA01/XRD'}, 'ω Angle': [{'ω Angle': -4}, {'ω Angle': -2}, {'ω Angle': 0}, {'ω Angle': 2}, {'ω Angle': 4}]}, 'X-ray Source': 'Cu K-α', 'XRD Model': 'Anton'}, 'sampleId': 'AAA01_DED-A', 'suffix': 'XRD', 'targetPath': 'AAA/DED-A/AAA01/XRD'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310ded1b56c53abc7e0fa4', 'updated': '2024-04-30T15:42:41.187000+00:00'}, {'_id': '66310f2e1b56c53abc7e19f4', 'created': '2024-04-30T15:33:02.807000+00:00', 'data': {'Completed By': 'Haoren', 'End Date': '2022-10-08', 'Start Date': '2022-10-07', 'Time Spent': '14:00', 'XRD Process Overview': {'Beam Amperage': 49, 'Beam Voltage': 40, 'Scan Type': '2θ-ω', 'UCSD Instrument Details': {'2θ Angle End': 80, '2θ Angle Start': 20, 'Scan Speed': 0.05, 'dataFiles': {'file': '', 'sampleId': 'AAA01_DED-B', 'targetPath': 'AAA/DED-B/AAA01/XRD'}, 'ω Angle': [{'ω Angle': -4}, {'ω Angle': -2}, {'ω Angle': 0}, {'ω Angle': 2}, {'ω Angle': 4}]}, 'X-ray Source': 'Cu K-α', 'XRD Model': 'Anton'}, 'sampleId': 'AAA01_DED-B', 'suffix': 'XRD', 'targetPath': 'AAA/DED-B/AAA01/XRD'}, 'files': [], 'folderId': '66310ca21b56c53abc7e0f9f', 'folders': [], 'formId': '66310ded1b56c53abc7e0fa4', 'updated': '2024-04-30T15:43:02.122000+00:00'}, {'_id': '66310f2f1b56c53abc7e19f9', 'created': '2024-04-30T15:33:03.110000+00:00', 'data': {'EBSD and EDS Mapping': {'Beam Current': 26, 'Beam Voltage': 20, 'Dwell Time': '4 x 1', 'Low Vacuum': '25', 'Sample Tilt': 60, 'Working Distance': 18.1}, 'EDS Quantitative Analysis': {'Beam Current': 3.2, 'Beam Voltage': 20, 'Dwell Time': 1, 'Low Vacuum': 'None', 'Sample Tilt': 0, 'Working Distance': 10}, 'Notes': '', 'Process Overview': {'End Date': '2022-10-09', 'SEM Used': 'Apreo (FEI)', 'Start Date': '2022-10-09', 'Time Spent': '03:00'}, 'Results': {'Measured Composition (%)': {'Al': 0, 'Co': 0, 'Cr': 0, 'Cu': 0, 'Fe': 0, 'Mn': 0, 'N ...

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.token = os.environ["GIRDER_TOKEN"]

# 1. List all collections and find the one named "BIRDSHOT (Center)"
collections = client.listCollection()
for col in collections:
    print(col['name'], col['_id'])
    # If col['name'] == 'BIRDSHOT (Center)', store its _id
    if col['name'] == 'BIRDSHOT (Center)':
        birdshot_collection_id = col['_id']

# 2. List the subfolders of the BIRDSHOT (Center) collection
folders = client.listFolder(birdshot_collection_id, parentType='collection')
for folder in folders:
    print(folder['name'], folder['_id'])
    # If folder['name'] == 'sample_data', store its _id
    if folder['name'] == 'sample_data':
        sample_data_folder_id = folder['_id']

# 3. List subfolders inside "sample_data"
subfolders = client.listFolder(sample_data_folder_id)
for sf in subfolders:
    print(sf['name'], sf['_id'])

# %%
df = birdshot.query("AAA")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = birdshot.query("AAA")
#
# NameError: name 'birdshot' is not defined

# %%
import sys
print(sys.executable)

# %%
import os
print(os.environ.get("GIRDER_API_URL"))
print(os.environ.get("GIRDER_API_KEY"))
print(os.environ.get("TMP_URL"))

# %%
import birdshot
import pandas as pd

data = birdshot.query("AAA", raw=True)  # Assuming you can modify or patch query to return early
df = pd.DataFrame.from_dict(data, orient='index')
print("Actual columns:", df.columns)

# %%
from girder_client import GirderClient
import os

client = GirderClient(apiUrl=os.environ["GIRDER_API_URL"])
client.authenticate(apiKey=os.environ["GIRDER_TOKEN"])

# Send the same query that birdshot.query("AAA") uses
raw_data = client.get(
    'entry/search',
    parameters={'query': '^AAA.._VAM-.', 'limit': 1000}
)

# If you want to preview what keys/structure it has:
import json
print(json.dumps(raw_data[:2], indent=2))  # print a couple entries

# Create a DataFrame to see the actual columns
import pandas as pd
df = pd.DataFrame.from_records(raw_data)
print("Actual columns:", df.columns.tolist())

# %%
import birdshot
import importlib

importlib.reload(birdshot)

# %%
birdshot.show_plot()

# %%
import birdshot
import os
import socket

# Find a free port
def get_free_port():
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind(('', 0))  # Let OS pick an available port
        return s.getsockname()[1]

free_port = get_free_port()
os.environ['TMP_URL'] = 'localhost:8888'  # This should match your running Jupyter server

def patched_show_plot():
    from dash import Dash
    import dash_bootstrap_components as dbc

    app = Dash(
        __name__,
        external_stylesheets=[dbc.themes.BOOTSTRAP, dbc.icons.FONT_AWESOME],
        requests_pathname_prefix=f"/proxy/{free_port}/",
    )
    app.layout = birdshot.serve_layout
    app.run(
        debug=False,
        jupyter_mode="jupyterlab",
        host="0.0.0.0",
        port=free_port,
        jupyter_server_url=f"http://{os.environ['TMP_URL']}/",
    )

birdshot.show_plot = patched_show_plot
birdshot.show_plot()

# %% [markdown]
# ### Working on understanding the queries to get something interesting into the dataframe

# %%
# Define the iteration value
iteration = 'AAA'

# Build the query string using the iteration variable
query_string = f"^{iteration}.._VAM-."

# Construct the birdshot.query statement (as it would be used)
query_statement = f"birdshot.query('entry/search', parameters={{'query': '{query_string}', 'limit': 1000}})"

# Print the constructed query statement
print(query_statement)

# %%
iteration = 'AAA'
raw_data = client.get(
        'entry/search', parameters={'query': f'^{iteration}.._VAM-.', 'limit': 1000}
)
raw_data[0]["data"]

# %%
birdshot.query('entry/search', parameters={'query': '^AAA.._VAM-.', 'limit': 1000})
